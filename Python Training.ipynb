# %%
print ('hello world')
# Out:
# hello world

# %%
#Variables in python

# %%
x=2
y=1
x+y
# Out:
# 3

# %%
#Variables: Variable simply nothing but value holder
#variables will be forminng as the building blocks in multiple while programing in python

# %%
#Rules for Variable:
    1) No name space while declaring the variables
    2) Variable should not start with number
    3) Variable name should not contain any special character eg. @,$,#,!

# %%
#Indroduction to Data type
Strings: str
Number (Float and Integer): int, float
List: list
Tuple: tuple
dictonary : dict

# %%
#Classification of Datatype
1) Mutable data type #flexible: We can edit and alter after declaration
2) Imutable data type #fixed: We can't edit and alter afte Declaration

# %%
Introduction to String Data type
"Series of Characters enclosed in quotes."
#Classification: Classified as an immutable 
#How to Define
1) Single quote   2) Double quote  3) Tripple quote

# %%
firstname='Chaitanya'
midname="Rajendra"
lastname='''Patil'''
print(firstname, " ",midname, " ", lastname)
# Out:
# Chaitanya   Rajendra   Patil

# %%
#String Method: Built in Progress in python

# %%
type method: It is used to knowing of the variable that we have defined
